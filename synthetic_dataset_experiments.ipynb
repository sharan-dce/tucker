# %%
! git clone https://github.com/sharan-dce/tucker.git
% cd tucker
! git checkout the_real_main
# Out:
# Cloning into 'tucker'...
# remote: Enumerating objects: 496, done.
# remote: Counting objects: 100% (496/496), done.
# remote: Compressing objects: 100% (320/320), done.
# remote: Total 496 (delta 287), reused 361 (delta 173), pack-reused 0
# Receiving objects: 100% (496/496), 15.34 MiB | 11.70 MiB/s, done.
# Resolving deltas: 100% (287/287), done.
# ...
# You can inspect what was checked out with 'git status'
# and retry the checkout with 'git checkout -f HEAD'
#
# ^C
# /content/tucker/tucker
# error: The following untracked working tree files would be overwritten by checkout:
# 	.gitignore
# 	README.md
# 	TODO
# 	__main__.py
# 	data/FB15k-237/.DS_Store
# 	data/FB15k-237/README.txt
# 	data/FB15k-237/test.txt
# 	data/FB15k-237/train.txt
# 	data/FB15k-237/valid.txt
# 	data/FB15k/.DS_Store
# 	data/FB15k/test.txt
# 	data/FB15k/train.txt
# 	data/FB15k/valid.txt
# 	data/WN18/README
# 	data/WN18/Wordnet3.0-LICENSE
# 	data/WN18/test.txt
# 	data/WN18/train.txt
# 	data/WN18/valid.txt
# ...

# %%
% cd training_scripts
# Out:
# /content/tucker/training_scripts

# %%
! python -u train_script.py\
    --model=tucker\
    --datapath=../data/inversion\
    --num_iterations=100\
    --batch_size=128\
    --lr=0.01\
    --dr=1.0\
    --edim=30\
    --rdim=1\
    --cuda=True\
    --input_dropout=0.0\
    --hidden_dropout1=0.0\
    --hidden_dropout2=0.0\
    --label_smoothing=0.0
# Out:
# Epoch 0: 100% 133/133 [00:00<00:00, 202.94it/s]
# Loss Val: 16.752137186937034
# Epoch 1: 100% 133/133 [00:00<00:00, 200.21it/s]
# Loss Val: 0.5381881801877171
# Epoch 2: 100% 133/133 [00:00<00:00, 197.54it/s]
# Loss Val: 0.2774787751259282
# Epoch 3: 100% 133/133 [00:00<00:00, 200.83it/s]
# Loss Val: 0.20732224837411195
# Epoch 4: 100% 133/133 [00:00<00:00, 200.33it/s]
# Loss Val: 0.17814359720796347
# Epoch 5: 100% 133/133 [00:00<00:00, 202.61it/s]
# Loss Val: 0.1624422372551635
# Epoch 6: 100% 133/133 [00:00<00:00, 202.90it/s]
# Loss Val: 0.15221317007672042
# Epoch 7: 100% 133/133 [00:00<00:00, 202.11it/s]
# Loss Val: 0.14440429909154773
# Epoch 8: 100% 133/133 [00:00<00:00, 197.65it/s]
# Loss Val: 0.13794996892102063
# Epoch 9: 100% 133/133 [00:00<00:00, 203.46it/s]
# Loss Val: 0.1323163312044926
# Measuring performance: 100% 24/24 [00:00<00:00, 89.77it/s]
# (0.003876272922594738, {1: 0.0006609385327164573, 3: 0.002974223397224058, 10: 0.00760079312623926})
# ...

# %%
! python -u train_script.py\
    --model=tucker\
    --datapath=../data/symmetry\
    --num_iterations=100\
    --batch_size=128\
    --lr=0.01\
    --dr=1.0\
    --edim=30\
    --rdim=2\
    --cuda=True\
    --input_dropout=0.0\
    --hidden_dropout1=0.0\
    --hidden_dropout2=0.0\
    --label_smoothing=0.0
# Out:
# Epoch 0: 100% 133/133 [00:00<00:00, 200.46it/s]
# Loss Val: 16.847100926097482
# Epoch 1: 100% 133/133 [00:00<00:00, 193.59it/s]
# Loss Val: 0.49655677331611514
# Epoch 2: 100% 133/133 [00:00<00:00, 198.12it/s]
# Loss Val: 0.26102429046295583
# Epoch 3: 100% 133/133 [00:00<00:00, 198.89it/s]
# Loss Val: 0.19938801939133555
# Epoch 4: 100% 133/133 [00:00<00:00, 196.03it/s]
# Loss Val: 0.17439619090873748
# Epoch 5: 100% 133/133 [00:00<00:00, 199.33it/s]
# Loss Val: 0.16145243227947503
# Epoch 6: 100% 133/133 [00:00<00:00, 201.69it/s]
# Loss Val: 0.15348705823998898
# Epoch 7: 100% 133/133 [00:00<00:00, 196.50it/s]
# Loss Val: 0.14765612571500242
# Epoch 8: 100% 133/133 [00:00<00:00, 197.39it/s]
# Loss Val: 0.1428772083017975
# Epoch 9: 100% 133/133 [00:00<00:00, 201.12it/s]
# Loss Val: 0.1384668118553236
# Measuring performance: 100% 24/24 [00:00<00:00, 91.29it/s]
# (0.00024918276904889436, {1: 0.0, 3: 0.0, 10: 0.0})
# Epoch 10: 100% 133/133 [00:00<00:00, 199.65it/s]
# ...

# %%
! python -u train_script.py\
    --model=tucker\
    --datapath=../data/composition\
    --num_iterations=500\
    --batch_size=128\
    --lr=0.05\
    --dr=0.995\
    --edim=20\
    --rdim=15\
    --cuda=True\
    --input_dropout=0.0\
    --hidden_dropout1=0.0\
    --hidden_dropout2=0.0\
    --label_smoothing=0.0
# Out:
# Epoch 0: 100% 141/141 [00:00<00:00, 199.39it/s]
# Loss Val: 5.142999619594775
# Epoch 1: 100% 141/141 [00:00<00:00, 202.51it/s]
# Loss Val: 0.2192566622979939
# Epoch 2: 100% 141/141 [00:00<00:00, 204.12it/s]
# Loss Val: 0.1890059548895806
# Epoch 3: 100% 141/141 [00:00<00:00, 201.43it/s]
# Loss Val: 0.1629983923630789
# Epoch 4: 100% 141/141 [00:00<00:00, 198.88it/s]
# Loss Val: 0.15119189547840506
# Epoch 5: 100% 141/141 [00:00<00:00, 202.41it/s]
# Loss Val: 0.14776884845923632
# Epoch 6: 100% 141/141 [00:00<00:00, 202.51it/s]
# Loss Val: 0.14515464706346393
# Epoch 7: 100% 141/141 [00:00<00:00, 197.41it/s]
# Loss Val: 0.14181175810517743
# Epoch 8: 100% 141/141 [00:00<00:00, 200.16it/s]
# Loss Val: 0.13707726239226758
# Epoch 9: 100% 141/141 [00:00<00:00, 199.90it/s]
# Loss Val: 0.13050107739400119
# Measuring performance: 100% 16/16 [00:00<00:00, 95.19it/s]
# (0.0005087451198229902, {1: 0.0, 3: 0.0, 10: 0.0})
# Epoch 10: 100% 141/141 [00:00<00:00, 200.31it/s]
# ...

# %%
! python -u train_script.py\
    --model=tucker\
    --datapath=../data/hierarchy2\
    --num_iterations=100\
    --batch_size=128\
    --lr=0.01\
    --dr=1.0\
    --edim=30\
    --rdim=2\
    --cuda=True\
    --input_dropout=0.0\
    --hidden_dropout1=0.0\
    --hidden_dropout2=0.0\
    --label_smoothing=0.0
# Out:
# Epoch 0: 100% 175/175 [00:00<00:00, 200.28it/s]
# Loss Val: 16.69436465855688
# Epoch 1: 100% 175/175 [00:00<00:00, 202.27it/s]
# Loss Val: 0.49622792890295386
# Epoch 2: 100% 175/175 [00:00<00:00, 201.11it/s]
# Loss Val: 0.295849654590711
# Epoch 3: 100% 175/175 [00:00<00:00, 201.03it/s]
# Loss Val: 0.2414590538246557
# Epoch 4: 100% 175/175 [00:00<00:00, 200.06it/s]
# Loss Val: 0.2174780920613557
# Epoch 5: 100% 175/175 [00:00<00:00, 201.16it/s]
# Loss Val: 0.20325046684592962
# Epoch 6: 100% 175/175 [00:00<00:00, 188.02it/s]
# Loss Val: 0.19272077025379986
# Epoch 7: 100% 175/175 [00:00<00:00, 196.67it/s]
# Loss Val: 0.18389708176255226
# Epoch 8: 100% 175/175 [00:00<00:00, 201.64it/s]
# Loss Val: 0.1751632168306969
# Epoch 9: 100% 175/175 [00:00<00:00, 199.82it/s]
# Loss Val: 0.16577352734748274
# Measuring performance: 100% 16/16 [00:00<00:00, 82.85it/s]
# (0.010829669280698704, {1: 0.0030241935483870967, 3: 0.008064516129032258, 10: 0.023185483870967742})
# ...
